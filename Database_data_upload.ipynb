# %%
from mysql.connector import MySQLConnection, Error
import pandas as pd
from sqlalchemy import create_engine 
import pymysql

from connection_config import read_db_config

# %% [markdown]
# Create connection arguments

# %%
conn_string,ssl_args = read_db_config('zuzana.teama')
engine = create_engine(conn_string,connect_args=ssl_args)

# %% [markdown]
# Load data into pandas dataframe and upload that then onto the database

# %%
#TotalLoad_2020_df = pd.read_csv('/Projects/BigDataChallenge/Big-Data-Challenge-Team-A/Data/TotalLoad_2020.csv',header = 0)
#TotalLoad_2020_df.to_sql('totalload_2020_entsoe_raw',con = engine,if_exists = 'fail')
